# %%
import numpy 
arr = numpy.array([1,2,3,4,5,6])
print(arr)
# Out:
# [1 2 3 4 5 6]

# %%
print('my name is prajay')
# Out:
# my name is prajay

# %%
import matplotlib.pyplot as plt 
year = [1950,1970,1998,2010]
population = [2.519,3.692,5.263,6.972]
x = plt.plot(year,population) # x,y axis #plots a line across the data points 
#x = plt.scatter(year,population) # to plot a scatter plot that only shows the data points not connected with a line 
#plt.xscale('log') #to print the xaxis on a logarithmic scale 
plt.show(x)

# %%
#plt.xscale('log')

# %%
list = [1,2,6,1,7,2,4,5,5,3,4,5,6,7,8,9]
plt.hist(list,bins = 3)
plt.show()
