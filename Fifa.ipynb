# %% [markdown]
# Working with Pandas

# %%
import pandas
fifa = pandas.read_csv('data.csv')
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
#to print the columns
#print(df.columns)

# %%
#to set a few colums of interest and then pass them to the dataframe and update it, or create a new variabe
#cols_of_interest = ['ID','Name','Age','Overall','Potential','Value','LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#       'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM','CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#       'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling','Curve', 'FKAccuracy', 'LongPassing','BallControl', 'Acceleration',
#       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower','Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression','Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure','StandingTackle', 'SlidingTackle']
#fifa2 = fifa2[cols_of_interest]
#fifa2

# %%
#put your columns in a list as a string 
#print(fifa.columns)
cols = list(fifa.columns)
#print(cols)
#Deletes columns after index 10
del cols [10:]
print(cols)
#Puts back the new list of columns in the dataframe
fifa2 = fifa[cols]
#drop specific columns
fifa2 = fifa2.drop(columns = ['Unnamed: 0', 'ID','Photo','Flag'])
fifa2.head()
# Out:
# ['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club']
#                 Name  Age Nationality  Overall  Potential                 Club
# 0           L. Messi   31   Argentina       94         94         FC Barcelona
# 1  Cristiano Ronaldo   33    Portugal       94         94             Juventus
# 2          Neymar Jr   26      Brazil       92         93  Paris Saint-Germain
# 3             De Gea   27       Spain       91         93    Manchester United
# 4       K. De Bruyne   27     Belgium       91         92      Manchester City

# %%
fifa2.dtypes
# Out:
# Name           object
# Age             int64
# Nationality    object
# Overall         int64
# Potential       int64
# Club           object
# dtype: object

# %%
#Locate all terms in fifa2 DF in the DF column 'Nationality' that is equal to India
fifa2.loc[fifa2['Nationality'] == 'India']
# Out:
#                   Name  Age Nationality  Overall  Potential Club
# 8605        S. Chhetri   33       India       67         67  NaN
# 10011       S. Jhingan   24       India       65         71  NaN
# 12598    J. Lalpekhlua   27       India       63         64  NaN
# 12811  G. Singh Sandhu   26       India       63         68  NaN
# 13508    A. Edathodika   31       India       62         62  NaN
# 14054        P. Halder   25       India       61         67  NaN
# 14199         P. Kotal   24       India       61         66  NaN
# 14218         L. Ralte   25       India       61         62  NaN
# 14705           N. Das   24       India       60         65  NaN
# 14786         U. Singh   22       India       60         67  NaN
# 14915       H. Narzary   24       India       60         66  NaN
# 15356         R. Singh   28       India       59         59  NaN
# 15643         S. Singh   22       India       59         65  NaN
# ...

# %%
cols = list (fifa.columns)
for i in cols:
    str.lower(i)
    cols.append(i)
print(cols)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-18-dbf3d4d72c00> in <module>
#       2 for i in cols:
#       3     str.lower(i)
# ----> 4     cols.append(i)
#       5 print(cols)
#
# MemoryError:
